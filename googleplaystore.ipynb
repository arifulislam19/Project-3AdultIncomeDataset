# %% [markdown]
# <a href="https://colab.research.google.com/github/arifulislam19/Project-3AdultIncomeDataset/blob/master/googleplaystore.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Library Import

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Data Import

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
file_path = '/content/drive/My Drive/Colab Notebooks/Data Analysis Project/googleplaystore.csv'

# %%
data = pd.read_csv(file_path)

# %% [markdown]
# 1. Display Top 5 Rows of The Dataset

# %%
data.head(5)
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %% [markdown]
# 2. Check Last 3 Rows of The Dataset

# %%
data.tail(3)
# Out:
#                                                  App             Category  \
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating             Genres      Last Updated         Current Ver  \
# 10838       Everyone            Medical  January 20, 2017                 1.0
# 10839     Mature 17+  Books & Reference  January 19, 2015  Varies with device
# 10840       Everyone          Lifestyle     July 25, 2018  Varies with device
#
#               Android Ver
# 10838          2.2 and up
# 10839  Varies with device
# ...

# %% [markdown]
# 3. Find Shape of Our Dataset (Number of Rows & Number of Columns)

# %%
print('Number of Rows: ',data.shape[0])
print('Number of Columns: ',data.shape[1])
# Out:
# Number of Rows:  10841
# Number of Columns:  13

# %% [markdown]
# 4. Get Information About Ourt Dataset Like Total Number Rows, Total Number of Columns, Datatypes of Each Column and Memory requirement

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %% [markdown]
# 5. Get Overall Statistics About The Dataframe

# %%
data.describe(include='all')
# Out:
#            App Category       Rating Reviews                Size    Installs  \
# count    10841    10841  9367.000000   10841               10841       10841
# unique    9660       34          NaN    6002                 462          22
# top     ROBLOX   FAMILY          NaN       0  Varies with device  1,000,000+
# freq         9     1972          NaN     596                1695        1579
# mean       NaN      NaN     4.193338     NaN                 NaN         NaN
# std        NaN      NaN     0.537431     NaN                 NaN         NaN
# min        NaN      NaN     1.000000     NaN                 NaN         NaN
# 25%        NaN      NaN     4.000000     NaN                 NaN         NaN
# 50%        NaN      NaN     4.300000     NaN                 NaN         NaN
# 75%        NaN      NaN     4.500000     NaN                 NaN         NaN
# max        NaN      NaN    19.000000     NaN                 NaN         NaN
#
# ...

# %% [markdown]
# 6. Total Number of App Titles Contain Astrology

# %%
data.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
len(data[data['App'].str.contains('Astrology', case=False)])
# Out:
# 3

# %% [markdown]
# 7. Find Average App Rating

# %%
data['Rating'].mean()
# Out:
# np.float64(4.193338315362443)

# %% [markdown]
# 8. Find Total Number of Unique Category

# %%
len(data['Category'].unique())
# Out:
# 34

# %% [markdown]
# 9. Which category getting the highest average rating

# %%
data.groupby('Category') ['Rating'].mean().sort_values(ascending=False)
# Out:
# Category
# 1.9                    19.000000
# EVENTS                  4.435556
# EDUCATION               4.389032
# ART_AND_DESIGN          4.358065
# BOOKS_AND_REFERENCE     4.346067
# PERSONALIZATION         4.335987
# PARENTING               4.300000
# GAME                    4.286326
# BEAUTY                  4.278571
# HEALTH_AND_FITNESS      4.277104
# SHOPPING                4.259664
# SOCIAL                  4.255598
# WEATHER                 4.244000
# SPORTS                  4.223511
# PRODUCTIVITY            4.211396
# HOUSE_AND_HOME          4.197368
# FAMILY                  4.192272
# PHOTOGRAPHY             4.192114
# AUTO_AND_VEHICLES       4.190411
# MEDICAL                 4.189143
# LIBRARIES_AND_DEMO      4.178462
# FOOD_AND_DRINK          4.166972
# COMMUNICATION           4.158537
# COMICS                  4.155172
# NEWS_AND_MAGAZINES      4.132189
# FINANCE                 4.131889
# ENTERTAINMENT           4.126174
# BUSINESS                4.121452
# ...

# %% [markdown]
# 10. Find Total Number of Apps having 5 star rating

# %%
data.sample(5)
# Out:
#                                                      App            Category  \
# 6140   Board Game Stats: Play tracking for tabletop g...           LIFESTYLE
# 1550                      Blackpink as if it's your last  LIBRARIES_AND_DEMO
# 10102                              EY Events Switzerland        PRODUCTIVITY
# 4348                 Mobizen Screen Recorder for SAMSUNG       VIDEO_PLAYERS
# 6508                                          Sam.BN Pro               TOOLS
#
#        Rating Reviews  Size     Installs  Type  Price Content Rating  \
# 6140      4.6     275  3.9M       5,000+  Paid  $2.99       Everyone
# 1550      4.7     831   24M     100,000+  Free      0       Everyone
# 10102     NaN       1   18M         500+  Free      0           Teen
# 4348      4.4  953894   37M  10,000,000+  Free      0       Everyone
# 6508      NaN      11  2.0M          10+  Paid  $0.99       Everyone
#
#                         Genres       Last Updated Current Ver  \
# ...

# %%
len(data[data['Rating'] == 5.0])
# Out:
# 274

# %% [markdown]
# 11. Find average value of reviews

# %%
data['Reviews']=data['Reviews'].replace('3.0M',3.0,inplace=True)
# Out:
# /tmp/ipython-input-210223623.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Reviews']=data['Reviews'].replace('3.0M',3.0,inplace=True)

# %%
data['Reviews']=(data['Reviews']).astype('float')

# %%
data['Reviews'].dtype
# Out:
# dtype('float64')

# %%
data['Reviews'].mean()
# Out:
# nan

# %%
data['Reviews']
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
#          ..
# 10836   NaN
# 10837   NaN
# 10838   NaN
# 10839   NaN
# 10840   NaN
# Name: Reviews, Length: 10841, dtype: float64

# %%
data
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
data = pd.read_csv(file_path)

# %%
data
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
data['Reviews'] = data['Reviews'].replace('3.0M', 3.0)

# %%
data['Reviews'] = data['Reviews'].astype('float')

# %%
data['Reviews'].dtype
# Out:
# dtype('float64')

# %%
data['Reviews'].mean()
# Out:
# np.float64(444111.9265750392)

# %% [markdown]
# 12. Find total number of free and paid apps

# %%
data.sample(5)
# Out:
#                                App Category  Rating  Reviews  Size  \
# 6684  B R Telco FCU Mobile Banking  FINANCE     4.7    413.0   13M
# 9033       PORTABLE SOCCER DX Lite   SPORTS     4.2  15068.0  2.5M
# 2252           Essential Anatomy 3  MEDICAL     4.1   1533.0   42M
# 1050             Citibanamex Movil  FINANCE     3.6  52306.0   42M
# 2534   Homeopathic Medicine Finder  MEDICAL     3.6     10.0   15M
#
#         Installs  Type   Price Content Rating   Genres       Last Updated  \
# 6684     10,000+  Free       0       Everyone  Finance       May 30, 2018
# 9033  1,000,000+  Free       0       Everyone   Sports      June 19, 2018
# 2252     50,000+  Paid  $11.99     Mature 17+  Medical     August 7, 2014
# 1050  5,000,000+  Free       0       Everyone  Finance      July 27, 2018
# 2534      1,000+  Free       0       Everyone  Medical  November 20, 2017
#
#      Current Ver   Android Ver
# 6684     5.9.1.0    5.0 and up
# 9033         3.4    2.3 and up
# ...

# %%
data['Type'].value_counts()
# Out:
# Type
# Free    10039
# Paid      800
# 0           1
# Name: count, dtype: int64

# %% [markdown]
# 13. Which app has maximum reviews

# %%
data.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
data[data['Reviews'].max() == data['Reviews']]['App']
# Out:
# 2544    Facebook
# Name: App, dtype: object

# %% [markdown]
# 14. Display top 5 apps having highest reviews

# %%
index = data['Reviews'].sort_values(ascending=False).head(5).index

# %%
data.iloc[index]['App']
# Out:
# 2544              Facebook
# 3943              Facebook
# 381     WhatsApp Messenger
# 336     WhatsApp Messenger
# 3904    WhatsApp Messenger
# Name: App, dtype: object

# %% [markdown]
# 15. Find average rating of free and paid apps

# %%
data.groupby('Type')['Rating'].mean()
# Out:
# Type
# 0       19.000000
# Free     4.186203
# Paid     4.266615
# Name: Rating, dtype: float64

# %% [markdown]
# 16. Display top 5 apps having maximum installs

# %%
data['Installs'].dtype
# Out:
# dtype('O')

# %%
data['Installs_1']=data['Installs'].str.replace(',','')

# %%
data['Installs_1']
# Out:
# 0           10000+
# 1          500000+
# 2         5000000+
# 3        50000000+
# 4          100000+
#            ...
# 10836        5000+
# 10837         100+
# 10838        1000+
# 10839        1000+
# 10840    10000000+
# Name: Installs_1, Length: 10841, dtype: object

# %%
data
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
data['Installs_1']=data['Installs_1'].str.replace('+','')

# %%
data
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
data[data['Installs_1']=='Free']
# Out:
#                                            App Category  Rating  Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0      3.0
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver Installs_1
# 10472       1.0.19  4.0 and up         NaN       Free

# %%
data['Installs_1'] = data['Installs_1'].replace('Free', '0')

# %%
data['Installs_1'] = data['Installs_1'].astype(int)

# %%
data[data['Installs_1'] == 'Free']
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver, Installs_1]
# Index: []

# %%
data
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
data['Installs_1'].astype('int')
# Out:
# 0           10000
# 1          500000
# 2         5000000
# 3        50000000
# 4          100000
#            ...
# 10836        5000
# 10837         100
# 10838        1000
# 10839        1000
# 10840    10000000
# Name: Installs_1, Length: 10841, dtype: int64

# %%
data['Installs_1'].dtype
# Out:
# dtype('int64')

# %%
index = data['Installs_1'].sort_values(ascending=False).head(5).index

# %%
data.iloc[index]['App']
# Out:
# 5856    Google Play Games
# 5395        Google Photos
# 2853        Google Photos
# 2884        Google Photos
# 4170         Google Drive
# Name: App, dtype: object
